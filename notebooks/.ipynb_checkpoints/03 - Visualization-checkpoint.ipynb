# %% [markdown]
# # Data Visualization

# %%
from pathlib import Path
import pandas as pd

# %%
path_base = Path.cwd()

# export path
path_export = Path.joinpath(path_base, "exports")
path_export.mkdir(parents=True, exist_ok=True)

# %%
# import the data from Notebook 02
temp = pd.read_pickle(Path.joinpath(path_export, "temp_final.pkl"))
prec = pd.read_pickle(Path.joinpath(path_export, "prec_final.pkl"))
sun = pd.read_pickle(Path.joinpath(path_export, "sun_final.pkl"))

temp_stations = pd.read_pickle(Path.joinpath(path_export, "temp_stations.pkl"))
prec_stations = pd.read_pickle(Path.joinpath(path_export, "prec_stations.pkl"))
sun_stations = pd.read_pickle(Path.joinpath(path_export, "sun_stations.pkl"))

landkreise = pd.read_pickle(Path.joinpath(path_export, "landkreise.pkl"))

# %% [markdown]
# ## Landkreis-Weather Station Assignment

# %%
pd.concat([landkreise, temp_stations], axis=0)
# Out:
#            Landkreis     Name kurz               Typ  IdLandkreis  \
# 0       SK Flensburg     Flensburg  Kreisfreie Stadt       1001.0
# 1            SK Kiel          Kiel  Kreisfreie Stadt       1002.0
# 2          SK Lübeck        Lübeck  Kreisfreie Stadt       1003.0
# 3      SK Neumünster    Neumünster  Kreisfreie Stadt       1004.0
# 4    LK Dithmarschen  Dithmarschen             Kreis       1051.0
# ..               ...           ...               ...          ...
# 653              NaN           NaN               NaN          NaN
# 654              NaN           NaN               NaN          NaN
# 655              NaN           NaN               NaN          NaN
# 656              NaN           NaN               NaN          NaN
# 657              NaN           NaN               NaN          NaN
#
#              Bundesland   latitude  longitude  station_id start_date  \
# 0    Schleswig-Holstein  54.784993   9.438528         NaN        NaT
# ...
