# %% [markdown]
# # Weather Data for DPPD Covid-19
# In this notebook we will download temperature, precipitation and sunshine duration data from _Deutscher Wetterdienst_ in order to include it into the Covid-19 Positive Deviance Analysis.
#
# Unfortunately, DWD does not provide access via an API, so we'll have to download the measurement data from each weather station for the last 500 days until yesterday and extract the desired information manually.
#
# Exact specifications of the data sets that are being used can be found here:
# - [temperature, hourly averages in Germany](https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/air_temperature/recent/BESCHREIBUNG_obsgermany_climate_hourly_tu_recent_de.pdf)
# - [precipitation, hourly averages in Germany](https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/precipitation/recent/BESCHREIBUNG_obsgermany_climate_hourly_precipitation_recent_de.pdf)
# - [sunshine duration, hourly in Germany](https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/sun/recent/BESCHREIBUNG_obsgermany_climate_hourly_sun_recent_de.pdf)

# %%
# web scraping
import requests
from bs4 import BeautifulSoup

# file handling
from pathlib import Path
from zipfile import ZipFile
import os
import shutil

# progress bar
from tqdm import tqdm
import time


import pandas as pd

# %% [markdown]
# ## URLs and Paths

# %%
# base urls to the server folders containing the data zip files
url_temp = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/air_temperature/recent/"
url_prec = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/precipitation/recent/"
url_sun = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/sun/recent/"
url_wind = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/wind/recent/"

# lists of the stations involved in measuring the corresponding data
url_temp_stations = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/air_temperature/recent/TU_Stundenwerte_Beschreibung_Stationen.txt"
url_prec_stations = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/precipitation/recent/RR_Stundenwerte_Beschreibung_Stationen.txt"
url_sun_stations = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/sun/recent/SD_Stundenwerte_Beschreibung_Stationen.txt"
url_wind_stations = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/wind/recent/FF_Stundenwerte_Beschreibung_Stationen.txt"

# create folders to place downloaded content in
path_base = Path.cwd()

path_downloads_temp = Path.joinpath(path_base, "downloads", "temp")
path_downloads_temp.mkdir(parents=True, exist_ok=True)

path_downloads_prec = Path.joinpath(path_base, "downloads", "prec")
path_downloads_prec.mkdir(parents=True, exist_ok=True)

path_downloads_sun = Path.joinpath(path_base, "downloads", "sun")
path_downloads_sun.mkdir(parents=True, exist_ok=True)

path_downloads_wind = Path.joinpath(path_base, "downloads", "wind")
path_downloads_wind.mkdir(parents=True, exist_ok=True)

# folders for exported content
path_export = Path.joinpath(path_base, "exports")
path_export.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Functions

# %%
def stations_description_parser(url):
    """Reads the stations description that lists all weather stations that participated in
       measuring the corresponding climate property.
       There exist around 700 stations that measure temperature and sun, and about 1000
       stations that measure precipitation.
    """
    req = requests.get(url)
    text = req.text.splitlines()

    data = []
    for line in text[2:]:
        e = line.split()
        station_id = e.pop(0)
        start_date = e.pop(0)
        end_date = e.pop(0)
        altitude = e.pop(0)
        latitude = e.pop(0)
        longitude = e.pop(0)
        state = e.pop(-1)
        station_name = " ".join(e)

        row = [station_id, start_date, end_date, altitude, latitude, longitude, station_name, state]
        data.append(row)

    columns = ["station_id", "start_date", "end_date", "altitude", "latitude", "longitude", "name", "state"]
    df = pd.DataFrame(data, columns=columns)
    
    # convert columns to numeric 
    df = df.apply(pd.to_numeric, errors="ignore")
    
    # convert dates into datetime objects
    df[["start_date", "end_date"]] = df[["start_date", "end_date"]].apply(pd.to_datetime, format="%Y%m%d")
    
    return df





def scrape_file_urls(url, prefix, suffix):
    """Find all zip files that are available on the DWD server.
    """
    req = requests.get(url)
    soup = BeautifulSoup(req.content, "html.parser")

    anchors = soup.find_all("a")
    links = []

    for a in anchors:
        ref = a.get("href")
        if ref.startswith(prefix) and ref.endswith(suffix):
            links.append(ref)
    return links
    
    
    
    
    
def download_zips(filenames, url_server, path_destination):
    """Downloads all zip files from the corresponding DWD server directory, extracts them and
       keeps only the zip file content.
    """

    if not Path(path_destination).is_dir():
        print("Invalid directory")
        return
    
    print(f"Downloading files from {url_server} to {path_destination}...")
    time.sleep(0.5) # otherwise progress bar gets messed up
    for file in tqdm(filenames):
        req = requests.get(url_server + file)

        filename = Path.joinpath(path_destination, file)
        filename.write_bytes(req.content)

        # unzip the file and only keep the extracted content
        with ZipFile(filename, "r") as zippy:
            dirname = Path.joinpath(path_destination, file[:-4])
            
            # remove already-existing directory from previous run of this notebook
            if os.path.isdir(dirname):
                try:
                    shutil.rmtree(dirname)
                except OSError as e:
                    print(e)
                    print("Old downloads could not be removed by the program. " +
                          "This might happen if you are working via SSH. " + 
                          "Try removing the corresponding folders manually.")

            try:
                dirname.mkdir()
                zippy.extractall(dirname)
                os.remove(filename)
            except Exception as e:
                print(e)
                
                
                
                
def scan_downloaded_folders(directory, prefix, suffix):
    """Searches the specified directory for folders that match the prefix and the suffix
       and returns a list of paths of all these folders.
    """
    
    dir_list = []

    dir_iter = os.scandir(directory)
    for i in dir_iter:
        if i.is_dir():
            name = i.name
            if name.startswith(prefix) and name.endswith(suffix):
                dir_list.append(Path.joinpath(directory, name))
    return dir_list

# %%
temp_filenames = scrape_file_urls(url_temp, "stundenwerte_TU_", "_akt.zip")
prec_filenames = scrape_file_urls(url_prec, "stundenwerte_RR_", "_akt.zip")
sun_filenames = scrape_file_urls(url_sun, "stundenwerte_SD_", "_akt.zip")
wind_filenames = scrape_file_urls(url_wind, "stundenwerte_FF_", "_akt.zip")

# %%
wind_filenames
# Out:
# ['stundenwerte_FF_00011_akt.zip',
#  'stundenwerte_FF_00090_akt.zip',
#  'stundenwerte_FF_00096_akt.zip',
#  'stundenwerte_FF_00102_akt.zip',
#  'stundenwerte_FF_00125_akt.zip',
#  'stundenwerte_FF_00161_akt.zip',
#  'stundenwerte_FF_00164_akt.zip',
#  'stundenwerte_FF_00183_akt.zip',
#  'stundenwerte_FF_00197_akt.zip',
#  'stundenwerte_FF_00198_akt.zip',
#  'stundenwerte_FF_00232_akt.zip',
#  'stundenwerte_FF_00282_akt.zip',
#  'stundenwerte_FF_00298_akt.zip',
#  'stundenwerte_FF_00303_akt.zip',
#  'stundenwerte_FF_00342_akt.zip',
#  'stundenwerte_FF_00368_akt.zip',
#  'stundenwerte_FF_00427_akt.zip',
#  'stundenwerte_FF_00430_akt.zip',
#  'stundenwerte_FF_00433_akt.zip',
#  'stundenwerte_FF_00460_akt.zip',
#  'stundenwerte_FF_00591_akt.zip',
#  'stundenwerte_FF_00596_akt.zip',
#  'stundenwerte_FF_00603_akt.zip',
#  'stundenwerte_FF_00619_akt.zip',
#  'stundenwerte_FF_00642_akt.zip',
#  'stundenwerte_FF_00656_akt.zip',
#  'stundenwerte_FF_00662_akt.zip',
#  'stundenwerte_FF_00691_akt.zip',
#  'stundenwerte_FF_00701_akt.zip',
#  'stundenwerte_FF_00704_akt.zip',
#  'stundenwerte_FF_00722_akt.zip',
#  'stundenwerte_FF_00766_akt.zip',
#  'stundenwerte_FF_00788_akt.zip',
#  'stundenwerte_FF_00840_akt.zip',
#  'stundenwerte_FF_00853_akt.zip',
#  'stundenwerte_FF_00856_akt.zip',
#  'stundenwerte_FF_00867_akt.zip',
#  'stundenwerte_FF_00880_akt.zip',
#  'stundenwerte_FF_00891_akt.zip',
#  'stundenwerte_FF_00953_akt.zip',
#  'stundenwerte_FF_00954_akt.zip',
#  'stundenwerte_FF_00963_akt.zip',
#  'stundenwerte_FF_01001_akt.zip',
#  'stundenwerte_FF_01011_akt.zip',
#  'stundenwerte_FF_01013_akt.zip',
#  'stundenwerte_FF_01048_akt.zip',
#  'stundenwerte_FF_01078_akt.zip',
#  'stundenwerte_FF_01200_akt.zip',
#  'stundenwerte_FF_01228_akt.zip',
#  'stundenwerte_FF_01262_akt.zip',
#  'stundenwerte_FF_01270_akt.zip',
#  'stundenwerte_FF_01303_akt.zip',
#  'stundenwerte_FF_01339_akt.zip',
#  'stundenwerte_FF_01346_akt.zip',
#  'stundenwerte_FF_01357_akt.zip',
#  'stundenwerte_FF_01358_akt.zip',
#  'stundenwerte_FF_01379_akt.zip',
#  'stundenwerte_FF_01420_akt.zip',
#  'stundenwerte_FF_01443_akt.zip',
#  'stundenwerte_FF_01468_akt.zip',
#  'stundenwerte_FF_01490_akt.zip',
#  'stundenwerte_FF_01503_akt.zip',
#  'stundenwerte_FF_01544_akt.zip',
#  'stundenwerte_FF_01550_akt.zip',
#  'stundenwerte_FF_01580_akt.zip',
#  'stundenwerte_FF_01587_akt.zip',
#  'stundenwerte_FF_01605_akt.zip',
#  'stundenwerte_FF_01612_akt.zip',
#  'stundenwerte_FF_01639_akt.zip',
#  'stundenwerte_FF_01684_akt.zip',
#  'stundenwerte_FF_01691_akt.zip',
#  'stundenwerte_FF_01694_akt.zip',
#  'stundenwerte_FF_01757_akt.zip',
#  'stundenwerte_FF_01759_akt.zip',
#  'stundenwerte_FF_01766_akt.zip',
#  'stundenwerte_FF_01803_akt.zip',
#  'stundenwerte_FF_01832_akt.zip',
#  'stundenwerte_FF_01869_akt.zip',
#  'stundenwerte_FF_01886_akt.zip',
#  'stundenwerte_FF_01963_akt.zip',
#  'stundenwerte_FF_01975_akt.zip',
#  'stundenwerte_FF_01993_akt.zip',
#  'stundenwerte_FF_02014_akt.zip',
#  'stundenwerte_FF_02023_akt.zip',
#  'stundenwerte_FF_02044_akt.zip',
#  'stundenwerte_FF_02100_akt.zip',
#  'stundenwerte_FF_02115_akt.zip',
#  'stundenwerte_FF_02171_akt.zip',
#  'stundenwerte_FF_02252_akt.zip',
#  'stundenwerte_FF_02261_akt.zip',
#  'stundenwerte_FF_02290_akt.zip',
#  'stundenwerte_FF_02303_akt.zip',
#  'stundenwerte_FF_02315_akt.zip',
#  'stundenwerte_FF_02349_akt.zip',
#  'stundenwerte_FF_02377_akt.zip',
#  'stundenwerte_FF_02385_akt.zip',
#  'stundenwerte_FF_02410_akt.zip',
#  'stundenwerte_FF_02429_akt.zip',
#  'stundenwerte_FF_02483_akt.zip',
#  'stundenwerte_FF_02485_akt.zip',
#  'stundenwerte_FF_02497_akt.zip',
#  'stundenwerte_FF_02559_akt.zip',
#  'stundenwerte_FF_02564_akt.zip',
#  'stundenwerte_FF_02573_akt.zip',
#  'stundenwerte_FF_02597_akt.zip',
#  'stundenwerte_FF_02601_akt.zip',
#  'stundenwerte_FF_02638_akt.zip',
#  'stundenwerte_FF_02667_akt.zip',
#  'stundenwerte_FF_02712_akt.zip',
#  'stundenwerte_FF_02773_akt.zip',
#  'stundenwerte_FF_02794_akt.zip',
#  'stundenwerte_FF_02812_akt.zip',
#  'stundenwerte_FF_02829_akt.zip',
#  'stundenwerte_FF_02856_akt.zip',
#  'stundenwerte_FF_02878_akt.zip',
#  'stundenwerte_FF_02886_akt.zip',
#  'stundenwerte_FF_02897_akt.zip',
#  'stundenwerte_FF_02905_akt.zip',
#  'stundenwerte_FF_02907_akt.zip',
#  'stundenwerte_FF_02925_akt.zip',
#  'stundenwerte_FF_02928_akt.zip',
#  'stundenwerte_FF_02932_akt.zip',
#  'stundenwerte_FF_02961_akt.zip',
#  'stundenwerte_FF_02985_akt.zip',
#  'stundenwerte_FF_03015_akt.zip',
#  'stundenwerte_FF_03023_akt.zip',
#  'stundenwerte_FF_03028_akt.zip',
#  'stundenwerte_FF_03032_akt.zip',
#  'stundenwerte_FF_03086_akt.zip',
#  'stundenwerte_FF_03093_akt.zip',
#  'stundenwerte_FF_03098_akt.zip',
#  'stundenwerte_FF_03126_akt.zip',
#  'stundenwerte_FF_03158_akt.zip',
#  'stundenwerte_FF_03166_akt.zip',
#  'stundenwerte_FF_03167_akt.zip',
#  'stundenwerte_FF_03196_akt.zip',
#  'stundenwerte_FF_03231_akt.zip',
#  'stundenwerte_FF_03244_akt.zip',
#  'stundenwerte_FF_03254_akt.zip',
#  'stundenwerte_FF_03268_akt.zip',
#  'stundenwerte_FF_03287_akt.zip',
#  'stundenwerte_FF_03321_akt.zip',
#  'stundenwerte_FF_03362_akt.zip',
#  'stundenwerte_FF_03366_akt.zip',
#  'stundenwerte_FF_03376_akt.zip',
#  'stundenwerte_FF_03379_akt.zip',
#  'stundenwerte_FF_03402_akt.zip',
#  'stundenwerte_FF_03484_akt.zip',
#  'stundenwerte_FF_03513_akt.zip',
#  'stundenwerte_FF_03534_akt.zip',
#  'stundenwerte_FF_03552_akt.zip',
#  'stundenwerte_FF_03623_akt.zip',
#  'stundenwerte_FF_03631_akt.zip',
#  'stundenwerte_FF_03639_akt.zip',
#  'stundenwerte_FF_03651_akt.zip',
#  'stundenwerte_FF_03660_akt.zip',
#  'stundenwerte_FF_03668_akt.zip',
#  'stundenwerte_FF_03730_akt.zip',
#  'stundenwerte_FF_03761_akt.zip',
#  'stundenwerte_FF_03811_akt.zip',
#  'stundenwerte_FF_03821_akt.zip',
#  'stundenwerte_FF_03897_akt.zip',
#  'stundenwerte_FF_03905_akt.zip',
#  'stundenwerte_FF_03925_akt.zip',
#  'stundenwerte_FF_03946_akt.zip',
#  'stundenwerte_FF_03987_akt.zip',
#  'stundenwerte_FF_04024_akt.zip',
#  'stundenwerte_FF_04032_akt.zip',
#  'stundenwerte_FF_04036_akt.zip',
#  'stundenwerte_FF_04039_akt.zip',
#  'stundenwerte_FF_04094_akt.zip',
#  'stundenwerte_FF_04104_akt.zip',
#  'stundenwerte_FF_04174_akt.zip',
#  'stundenwerte_FF_04177_akt.zip',
#  'stundenwerte_FF_04225_akt.zip',
#  'stundenwerte_FF_04271_akt.zip',
#  'stundenwerte_FF_04279_akt.zip',
#  'stundenwerte_FF_04280_akt.zip',
#  'stundenwerte_FF_04336_akt.zip',
#  'stundenwerte_FF_04371_akt.zip',
#  'stundenwerte_FF_04393_akt.zip',
#  'stundenwerte_FF_04464_akt.zip',
#  'stundenwerte_FF_04466_akt.zip',
#  'stundenwerte_FF_04501_akt.zip',
#  'stundenwerte_FF_04625_akt.zip',
#  'stundenwerte_FF_04642_akt.zip',
#  'stundenwerte_FF_04745_akt.zip',
#  'stundenwerte_FF_04880_akt.zip',
#  'stundenwerte_FF_04887_akt.zip',
#  'stundenwerte_FF_04911_akt.zip',
#  'stundenwerte_FF_04919_akt.zip',
#  'stundenwerte_FF_04928_akt.zip',
#  'stundenwerte_FF_04931_akt.zip',
#  'stundenwerte_FF_04947_akt.zip',
#  'stundenwerte_FF_05029_akt.zip',
#  'stundenwerte_FF_05078_akt.zip',
#  'stundenwerte_FF_05100_akt.zip',
#  'stundenwerte_FF_05109_akt.zip',
#  'stundenwerte_FF_05142_akt.zip',
#  'stundenwerte_FF_05158_akt.zip',
#  'stundenwerte_FF_05319_akt.zip',
#  'stundenwerte_FF_05327_akt.zip',
#  'stundenwerte_FF_05347_akt.zip',
#  'stundenwerte_FF_05349_akt.zip',
#  'stundenwerte_FF_05371_akt.zip',
#  'stundenwerte_FF_05397_akt.zip',
#  'stundenwerte_FF_05404_akt.zip',
#  'stundenwerte_FF_05412_akt.zip',
#  'stundenwerte_FF_05426_akt.zip',
#  'stundenwerte_FF_05440_akt.zip',
#  'stundenwerte_FF_05480_akt.zip',
#  'stundenwerte_FF_05490_akt.zip',
#  'stundenwerte_FF_05516_akt.zip',
#  'stundenwerte_FF_05538_akt.zip',
#  'stundenwerte_FF_05546_akt.zip',
#  'stundenwerte_FF_05629_akt.zip',
#  'stundenwerte_FF_05640_akt.zip',
#  'stundenwerte_FF_05705_akt.zip',
#  'stundenwerte_FF_05715_akt.zip',
#  'stundenwerte_FF_05779_akt.zip',
#  'stundenwerte_FF_05792_akt.zip',
#  'stundenwerte_FF_05797_akt.zip',
#  'stundenwerte_FF_05800_akt.zip',
#  'stundenwerte_FF_05825_akt.zip',
#  'stundenwerte_FF_05839_akt.zip',
#  'stundenwerte_FF_05851_akt.zip',
#  'stundenwerte_FF_05856_akt.zip',
#  'stundenwerte_FF_05871_akt.zip',
#  'stundenwerte_FF_05877_akt.zip',
#  'stundenwerte_FF_05906_akt.zip',
#  'stundenwerte_FF_05930_akt.zip',
#  'stundenwerte_FF_06091_akt.zip',
#  'stundenwerte_FF_06096_akt.zip',
#  'stundenwerte_FF_06097_akt.zip',
#  'stundenwerte_FF_06099_akt.zip',
#  'stundenwerte_FF_06101_akt.zip',
#  'stundenwerte_FF_06102_akt.zip',
#  'stundenwerte_FF_06103_akt.zip',
#  'stundenwerte_FF_06106_akt.zip',
#  'stundenwerte_FF_06107_akt.zip',
#  'stundenwerte_FF_06108_akt.zip',
#  'stundenwerte_FF_06159_akt.zip',
#  'stundenwerte_FF_06163_akt.zip',
#  'stundenwerte_FF_06196_akt.zip',
#  'stundenwerte_FF_06197_akt.zip',
#  'stundenwerte_FF_06211_akt.zip',
#  'stundenwerte_FF_06238_akt.zip',
#  'stundenwerte_FF_06253_akt.zip',
#  'stundenwerte_FF_06314_akt.zip',
#  'stundenwerte_FF_06344_akt.zip',
#  'stundenwerte_FF_07308_akt.zip',
#  'stundenwerte_FF_07341_akt.zip',
#  'stundenwerte_FF_07351_akt.zip',
#  'stundenwerte_FF_07367_akt.zip',
#  'stundenwerte_FF_07368_akt.zip',
#  'stundenwerte_FF_07369_akt.zip',
#  'stundenwerte_FF_07370_akt.zip',
#  'stundenwerte_FF_07374_akt.zip',
#  'stundenwerte_FF_07389_akt.zip',
#  'stundenwerte_FF_07391_akt.zip',
#  'stundenwerte_FF_07392_akt.zip',
#  'stundenwerte_FF_07393_akt.zip',
#  'stundenwerte_FF_07394_akt.zip',
#  'stundenwerte_FF_07395_akt.zip',
#  'stundenwerte_FF_07396_akt.zip',
#  'stundenwerte_FF_07403_akt.zip',
#  'stundenwerte_FF_07410_akt.zip',
#  'stundenwerte_FF_07412_akt.zip',
#  'stundenwerte_FF_07416_akt.zip',
#  'stundenwerte_FF_10510_akt.zip',
#  'stundenwerte_FF_13674_akt.zip',
#  'stundenwerte_FF_13676_akt.zip',
#  'stundenwerte_FF_13693_akt.zip',
#  'stundenwerte_FF_13701_akt.zip',
#  'stundenwerte_FF_13711_akt.zip',
#  'stundenwerte_FF_13900_akt.zip',
#  'stundenwerte_FF_13901_akt.zip',
#  'stundenwerte_FF_13932_akt.zip',
#  'stundenwerte_FF_13952_akt.zip',
#  'stundenwerte_FF_13965_akt.zip',
#  'stundenwerte_FF_15000_akt.zip',
#  'stundenwerte_FF_15044_akt.zip',
#  'stundenwerte_FF_15120_akt.zip',
#  'stundenwerte_FF_15122_akt.zip',
#  'stundenwerte_FF_15189_akt.zip',
#  'stundenwerte_FF_15190_akt.zip',
#  'stundenwerte_FF_15200_akt.zip',
#  'stundenwerte_FF_15207_akt.zip',
#  'stundenwerte_FF_15214_akt.zip',
#  'stundenwerte_FF_15444_akt.zip',
#  'stundenwerte_FF_15520_akt.zip',
#  'stundenwerte_FF_15547_akt.zip',
#  'stundenwerte_FF_15976_akt.zip',
#  'stundenwerte_FF_15978_akt.zip']

# %%
# download all the zip files (about 960 MB)
answer = None
answer = input("Do you want to download 1GB? (y/n)")
if answer == "y":
    download_zips(temp_filenames, url_temp, path_downloads_temp)
    download_zips(prec_filenames, url_prec, path_downloads_prec)
    download_zips(sun_filenames, url_sun, path_downloads_sun)
    download_zips(wind_filenames, url_wind, path_downloads_wind)
# Out:
# Do you want to download 1GB? (y/n)y
# Downloading files from https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/air_temperature/recent/ to /Users/fynnwithake/Code/dppd_weather/notebooks/downloads/temp...
# 100%|██████████| 508/508 [01:52<00:00,  4.53it/s]
# Downloading files from https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/precipitation/recent/ to /Users/fynnwithake/Code/dppd_weather/notebooks/downloads/prec...
# 100%|██████████| 972/972 [02:57<00:00,  5.49it/s]
# Downloading files from https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/sun/recent/ to /Users/fynnwithake/Code/dppd_weather/notebooks/downloads/sun...
# 100%|██████████| 303/303 [00:55<00:00,  5.47it/s]
# Downloading files from https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/hourly/wind/recent/ to /Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind...
# 100%|██████████| 294/294 [00:59<00:00,  4.92it/s]

# %%
# find downloaded folders
downloaded_temp_folders = scan_downloaded_folders(path_downloads_temp, "stundenwerte_TU_", "_akt")
downloaded_prec_folders = scan_downloaded_folders(path_downloads_prec, "stundenwerte_RR_", "_akt")
downloaded_sun_folders = scan_downloaded_folders(path_downloads_sun, "stundenwerte_SD_", "_akt")
downloaded_wind_folders = scan_downloaded_folders(path_downloads_wind, "stundenwerte_FF_", "_akt")
downloaded_wind_folders
# Out:
# [PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01200_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01228_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04393_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03167_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05516_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03761_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04032_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03946_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04225_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00282_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01639_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01605_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01759_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03166_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02907_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03402_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05715_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03366_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02044_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02905_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05930_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01001_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02252_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03158_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02483_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02497_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06197_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00096_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05851_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06196_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04024_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03987_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01612_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02290_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01766_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00691_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00642_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00656_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02928_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05538_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03015_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00722_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05100_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03028_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03821_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01011_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01993_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03362_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03376_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00125_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05705_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04625_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01013_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04745_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01832_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02485_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06344_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13952_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00090_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01358_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04036_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03639_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00867_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15000_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07410_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07389_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06097_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02597_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06108_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02385_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03925_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05825_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05158_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01869_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04911_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06096_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04642_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00342_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01048_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00430_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02794_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00183_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00197_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01262_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00368_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00591_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03098_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02812_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00963_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05629_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04279_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13711_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15189_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05371_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00433_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00427_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03660_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07412_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07374_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15200_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00619_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15214_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01503_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07370_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07416_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06091_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05349_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04094_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01339_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13701_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13932_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03513_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05412_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07403_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01270_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13674_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02023_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04336_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06253_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13676_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15207_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03897_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07367_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15978_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01886_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00232_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05404_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04280_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02829_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04928_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00596_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02961_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05029_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04104_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07394_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02429_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06101_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01691_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03086_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04931_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04919_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00766_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02171_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05839_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13901_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13900_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00954_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04501_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03534_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03905_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01684_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03093_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05347_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07395_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04887_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00161_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03126_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03668_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07368_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06102_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03244_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04271_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06314_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03287_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01490_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02601_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06103_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15976_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07396_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07369_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07341_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13693_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05797_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02985_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15547_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04466_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03321_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03484_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02573_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05546_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04880_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07351_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03651_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07392_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06107_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02349_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05426_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05397_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15190_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05142_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00953_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01443_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03254_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02638_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03268_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03730_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06106_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06099_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07393_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05792_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00198_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05779_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02014_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00603_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02564_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07391_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02410_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01694_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00011_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05800_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00788_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01468_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02377_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02559_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01078_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04464_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02773_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00164_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04371_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05906_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07308_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03032_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15122_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05319_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05480_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00704_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05640_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03231_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01803_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04947_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06163_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01963_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02932_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00102_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03379_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00880_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01544_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01550_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05078_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01587_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03623_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01975_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05440_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02878_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05871_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02886_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01357_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15444_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05327_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04039_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15120_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03811_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02925_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00840_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02712_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15520_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01757_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15044_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00298_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02100_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05109_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_10510_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13965_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01346_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02897_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01420_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02115_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02667_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06159_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03196_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04174_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00460_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00662_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06211_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00853_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02261_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03631_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02315_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03023_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05877_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03552_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00701_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01379_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05490_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04177_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01580_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00891_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06238_akt')]

# %%
downloaded_wind_folders
# Out:
# [PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01200_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01228_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04393_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03167_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05516_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03761_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04032_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03946_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04225_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00282_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01639_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01605_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01759_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03166_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02907_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03402_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05715_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03366_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02044_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02905_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05930_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01001_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02252_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03158_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02483_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02497_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06197_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00096_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05851_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06196_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04024_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03987_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01612_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02290_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01766_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00691_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00642_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00656_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02928_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05538_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03015_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00722_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05100_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03028_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03821_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01011_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01993_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03362_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03376_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00125_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05705_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04625_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01013_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04745_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01832_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02485_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06344_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13952_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00090_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01358_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04036_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03639_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00867_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15000_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07410_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07389_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06097_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02597_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06108_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02385_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03925_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05825_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05158_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01869_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04911_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06096_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04642_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00342_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01048_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00430_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02794_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00183_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00197_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01262_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00368_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00591_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03098_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02812_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00963_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05629_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04279_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13711_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15189_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05371_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00433_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00427_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03660_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07412_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07374_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15200_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00619_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15214_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01503_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07370_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07416_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06091_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05349_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04094_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01339_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13701_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13932_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03513_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05412_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07403_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01270_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13674_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02023_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04336_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06253_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13676_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15207_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03897_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07367_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15978_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01886_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00232_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05404_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04280_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02829_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04928_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00596_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02961_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05029_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04104_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07394_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02429_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06101_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01691_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03086_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04931_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04919_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00766_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02171_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05839_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13901_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13900_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00954_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04501_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03534_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03905_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01684_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03093_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05347_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07395_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04887_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00161_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03126_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03668_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07368_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06102_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03244_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04271_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06314_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03287_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01490_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02601_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06103_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15976_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07396_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07369_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07341_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13693_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05797_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02985_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15547_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04466_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03321_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03484_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02573_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05546_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04880_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07351_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03651_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07392_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06107_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02349_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05426_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05397_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15190_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05142_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00953_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01443_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03254_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02638_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03268_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03730_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06106_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06099_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07393_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05792_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00198_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05779_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02014_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00603_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02564_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07391_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02410_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01694_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00011_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05800_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00788_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01468_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02377_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02559_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01078_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04464_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02773_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00164_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04371_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05906_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_07308_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03032_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15122_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05319_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05480_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00704_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05640_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03231_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01803_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04947_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06163_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01963_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02932_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00102_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03379_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00880_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01544_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01550_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05078_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01587_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03623_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01975_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05440_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02878_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05871_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02886_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01357_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15444_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05327_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04039_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15120_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03811_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02925_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00840_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02712_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15520_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01757_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_15044_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00298_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02100_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05109_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_10510_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_13965_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01346_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02897_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01420_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02115_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02667_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06159_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02303_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03196_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04174_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00460_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00662_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06211_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00853_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02261_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03631_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02315_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03023_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05877_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_02856_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_03552_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00701_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01379_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_05490_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_04177_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_01580_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_00891_akt'),
#  PosixPath('/Users/fynnwithake/Code/dppd_weather/notebooks/downloads/wind/stundenwerte_FF_06238_akt')]

# %%
def find_product_file(directory, prefix, suffix):
    """Searches the extracted content of a downloaded zip file for the product file,
       which contains the information we are interested in. There exist additional files
       that provide meta data which we will ignore for now.
    """
    file_list = []
    
    dir_iter = os.scandir(directory)
    for i in dir_iter:
        if i.is_file():
            name = i.name
            if name.startswith(prefix) and name.endswith(suffix):
                file_list.append(Path.joinpath(directory, name))
    
    # make sure that only one product file was contained in the folder
    if len(file_list) == 1:
        return file_list[0]
    elif len(file_list) > 1:
        raise Exception("There seem to exist two product files for the same station!")
    else:
        raise Exception("No product file found!")

        
        

def temp_to_dataframe(file_path):
    """Converts the downloaded temperature text file into a pandas dataframe.
    """
    text = file_path.read_text()
    text = text.splitlines()
    
    data = []
    for line in text[1:]:
        row = line.split(";")
        values = [value.strip() for value in row]
        values.pop()
        data.append(values)

    colnames = ["station_id", "date", "quality", "temperature", "humidity"]
    df = pd.DataFrame(data, columns=colnames)

    # TODO apply processing to columns (e.g. datetime)

    return df



def prec_to_dataframe(file_path):
    text = file_path.read_text()
    text = text.splitlines()
    
    data = []
    for line in text[1:]:
        row = line.split(";")
        values = [value.strip() for value in row]
        values.pop()
        data.append(values)

    colnames = ["station_id", "date", "quality", "R1", "R1_IND", "WRTR"]
    df = pd.DataFrame(data, columns=colnames)


    # TODO apply processing to columns (e.g. datetime)

    return df



def sun_to_dataframe(file_path):
    text = file_path.read_text()
    text = text.splitlines()
    
    data = []
    for line in text[1:]:
        row = line.split(";")
        values = [value.strip() for value in row]
        values.pop()
        data.append(values)

    colnames = ["station_id", "date", "quality", "SD_SO"]
    df = pd.DataFrame(data, columns=colnames)

    # TODO apply processing to columns (e.g. datetime)

    return df

def wind_to_dataframe(file_path):
    """Converts the downloaded wind text file into a pandas dataframe.
    """
    text = file_path.read_text()
    text = text.splitlines()
    
    data = []
    for line in text[1:]:
        row = line.split(";")
        values = [value.strip() for value in row]
        values.pop()
        data.append(values)

    colnames = ["station_id", "date", "quality", "velocity", "direction"]
    df = pd.DataFrame(data, columns=colnames)

    # TODO apply processing to columns (e.g. datetime)

    return df

def collect_all_product_files(dirlist, prefix, suffix):
    frames = []
    for folder_name in dirlist:
        #path = Path.joinpath(rootdir, folder_name)
        path = Path(folder_name)
        # find product file name
        try:
            product_file = find_product_file(path, prefix, suffix)
        except:
            print("Product file not found")
            continue

        # extract the data from this file
        if prefix == "produkt_tu_stunde_":
            df = temp_to_dataframe(product_file)
            frames.append(df)
        elif prefix == "produkt_rr_stunde_":
            df = prec_to_dataframe(product_file)
        elif prefix == "produkt_sd_stunde_":
            df = sun_to_dataframe(product_file)
        elif prefix == "produkt_ff_stunde_":
            df = wind_to_dataframe(product_file)
        else:
            raise Exception(f"Unsupported prefix {prefix}!")
            
        frames.append(df)

    # concatenate all the frames into one frame
    return pd.concat(frames)

# %%
# extract all data
df_temp = collect_all_product_files(downloaded_temp_folders, "produkt_tu_stunde_", ".txt")
df_prec = collect_all_product_files(downloaded_prec_folders, "produkt_rr_stunde_", ".txt")
df_sun = collect_all_product_files(downloaded_sun_folders, "produkt_sd_stunde_", ".txt")
df_wind = collect_all_product_files(downloaded_wind_folders, "produkt_ff_stunde_", ".txt")

# %%
df_wind
# Out:
#    station_id        date quality velocity direction
# 0        1200  2018111500      10      3.2       160
# 1        1200  2018111501      10      2.1       150
# 2        1200  2018111502      10      2.1       130
# 3        1200  2018111503      10      2.5       140
# 4        1200  2018111504      10      2.2       150
# ..        ...         ...     ...      ...       ...
# 17       6238  2017072917      10      1.1       150
# 18       6238  2017072918      10      1.2       130
# 19       6238  2017072919      10      0.8       160
# 20       6238  2017072920      10      1.1       170
# 21       6238  2017072921      10      0.9       110
#
# [3706597 rows x 5 columns]

# %%
df_temp_stations = stations_description_parser(url_temp_stations)
df_prec_stations = stations_description_parser(url_prec_stations)
df_sun_stations = stations_description_parser(url_sun_stations)
df_wind_stations = stations_description_parser(url_wind_stations)
df_wind_stations
# Out:
#      station_id start_date   end_date  altitude  latitude  longitude  \
# 0             3 1937-01-01 2011-03-31       202   50.7827     6.0941
# 1            11 1980-09-01 2020-05-17       680   47.9737     8.5205
# 2            44 1969-01-01 1995-11-30        44   52.9336     8.2370
# 3            52 1969-01-01 2001-12-31        46   53.6623    10.1990
# 4            72 1978-09-01 1995-05-31       794   48.2766     9.0001
# ..          ...        ...        ...       ...       ...        ...
# 514       15444 2014-09-01 2020-05-17       593   48.4418     9.9216
# 515       15520 2015-09-01 2020-05-17       656   47.8190    12.2956
# 516       15547 2016-10-01 2020-05-17       215   49.1259     9.1428
# 517       15976 2020-04-01 2020-05-17       216   49.9529     8.2107
# 518       15978 2020-04-01 2020-05-17       316   49.5044     7.8618
#
#                             name                state
# 0                         Aachen  Nordrhein-Westfalen
# 1    Donaueschingen (Landeplatz)    Baden-Württemberg
# 2                   Großenkneten        Niedersachsen
# 3           Ahrensburg-Wulfsdorf   Schleswig-Holstein
# 4         Albstadt-Onstmettingen    Baden-Württemberg
# ..                           ...                  ...
# 514                Ulm-Mähringen    Baden-Württemberg
# 515         Frasdorf-Greimelberg               Bayern
# 516             Heilbronn/Neckar    Baden-Württemberg
# 517              Ober-Olm/Bellem      Rheinland-Pfalz
# 518                      Sembach      Rheinland-Pfalz
#
# [519 rows x 8 columns]

# %% [markdown]
# ## Data Cleaning

# %%
def clean_data(df):
    df = df.apply(pd.to_numeric)
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d%H")

    # -999 = missing data
    if 'temperature' in df.columns:
        df.loc[df["temperature"] == -999, "temperature"] = float("NaN")
    if 'humidity' in df.columns:
        df.loc[df["humidity"] == -999, "humidity"] = float("NaN")
    if 'R1' in df.columns:
        df.loc[df["R1"] == -999, "R1"] = float("NaN")
    if 'R1_IND' in df.columns:
        df.loc[df["R1_IND"] == -999, "R1_IND"] = float("NaN")
    if 'SD_SO' in df.columns:
        df.loc[df["SD_SO"] == -999, "SD_SO"] = float("NaN")
    if 'velocity' in df.columns:
        df.loc[df["velocity"] == -999, "velocity"] = float("NaN")
    if 'direction' in df.columns:
        df.loc[df["direction"] == -999, "direction"] = float("NaN")
    return df

df_temp = clean_data(df_temp)
df_prec = clean_data(df_prec)
df_sun = clean_data(df_sun)
df_wind = clean_data(df_wind)

# %%
df_temp.sample(20)
# Out:
#        station_id                date  quality  temperature  humidity
# 8469         3904 2019-11-02 21:00:00        3         10.3      91.0
# 675          1645 2018-12-13 03:00:00        3          0.4      93.0
# 5022         3166 2019-06-12 06:00:00        3         18.5      89.0
# 8630         4911 2019-11-09 14:00:00        3          6.9      78.0
# 800          1279 2018-12-18 08:00:00        3          2.3      99.0
# 2588         6259 2019-03-02 20:00:00        3          6.7      80.0
# 1675          853 2019-01-23 19:00:00        3         -8.2      87.0
# 12841        6337 2020-05-03 01:00:00        1          4.9      99.0
# 10388         850 2020-01-22 14:00:00        3          4.7      96.0
# 5607         6275 2019-07-06 15:00:00        3         28.7      31.0
# 5374         2600 2019-06-26 22:00:00        3         24.8      78.0
# 211          2886 2018-11-23 23:00:00        3          1.2      99.0
# 5716         7368 2019-07-11 04:00:00        3         12.6      93.0
# 6171          704 2019-07-30 03:00:00        3         16.5      93.0
# 9861         3231 2019-12-30 21:00:00        3         -1.2      79.0
# 4787          403 2019-06-02 11:00:00        3         26.9      43.0
# 12241        3875 2020-04-08 01:00:00        1         10.6      48.0
# 9246         3244 2019-12-05 06:00:00        3         -2.4      99.0
# 495          2575 2018-12-05 15:00:00        3          4.8      96.0
# 5488         6263 2019-07-01 16:00:00        3         28.9      53.0

# %%
df_wind.dtypes
# Out:
# station_id             int64
# date          datetime64[ns]
# quality                int64
# velocity             float64
# direction            float64
# dtype: object

# %%
# Discard all data from before 2020
df_temp = df_temp[df_temp['date'].dt.year == 2020]
df_prec = df_prec[df_prec['date'].dt.year == 2020]
df_sun = df_sun[df_sun['date'].dt.year == 2020]
df_wind = df_wind[df_wind['date'].dt.year == 2020]

# %%
# export as pickle
df_temp.to_pickle(Path.joinpath(path_export, "temp.pkl"))
df_temp_stations.to_pickle(Path.joinpath(path_export, "temp_stations.pkl"))

df_prec.to_pickle(Path.joinpath(path_export, "prec.pkl"))
df_prec_stations.to_pickle(Path.joinpath(path_export, "prec_stations.pkl"))

df_sun.to_pickle(Path.joinpath(path_export, "sun.pkl"))
df_prec_stations.to_pickle(Path.joinpath(path_export, "sun_stations.pkl"))

df_wind.to_pickle(Path.joinpath(path_export, "wind.pkl"))
df_wind_stations.to_pickle(Path.joinpath(path_export, "wind_stations.pkl"))

# %%
pd.merge(df_wind, df_wind_stations, on='station_id')
# Out:
#         station_id                date  quality  velocity  direction  \
# 0             1200 2020-01-01 00:00:00        3       2.6      280.0
# 1             1200 2020-01-01 01:00:00        3       3.2      260.0
# 2             1200 2020-01-01 02:00:00        3       3.2      260.0
# 3             1200 2020-01-01 03:00:00        3       2.8      250.0
# 4             1200 2020-01-01 04:00:00        3       3.6      250.0
# ...            ...                 ...      ...       ...        ...
# 923191         891 2020-05-17 19:00:00        1       7.1      270.0
# 923192         891 2020-05-17 20:00:00        1       7.5      270.0
# 923193         891 2020-05-17 21:00:00        1       6.6      270.0
# 923194         891 2020-05-17 22:00:00        1       6.0      260.0
# 923195         891 2020-05-17 23:00:00        1       5.5      260.0
#
#        start_date   end_date  altitude  latitude  longitude          name  \
# 0      2007-11-20 2020-05-17         3   54.0691     9.0105  Elpersbüttel
# 1      2007-11-20 2020-05-17         3   54.0691     9.0105  Elpersbüttel
# 2      2007-11-20 2020-05-17         3   54.0691     9.0105  Elpersbüttel
# 3      2007-11-20 2020-05-17         3   54.0691     9.0105  Elpersbüttel
# 4      2007-11-20 2020-05-17         3   54.0691     9.0105  Elpersbüttel
# ...           ...        ...       ...       ...        ...           ...
# 923191 1969-01-01 2020-05-17         5   53.8713     8.7058      Cuxhaven
# 923192 1969-01-01 2020-05-17         5   53.8713     8.7058      Cuxhaven
# 923193 1969-01-01 2020-05-17         5   53.8713     8.7058      Cuxhaven
# 923194 1969-01-01 2020-05-17         5   53.8713     8.7058      Cuxhaven
# 923195 1969-01-01 2020-05-17         5   53.8713     8.7058      Cuxhaven
#
#                      state
# 0       Schleswig-Holstein
# 1       Schleswig-Holstein
# 2       Schleswig-Holstein
# 3       Schleswig-Holstein
# 4       Schleswig-Holstein
# ...                    ...
# 923191       Niedersachsen
# 923192       Niedersachsen
# 923193       Niedersachsen
# 923194       Niedersachsen
# 923195       Niedersachsen
#
# [923196 rows x 12 columns]
